# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Memuat dataset dari file CSV
file_path = 'iris.csv'
df = pd.read_csv(file_path)

# Scatter Plot: Sepal Length vs Sepal Width
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='sepal_length', y='sepal_width', hue='species', palette='viridis')
plt.title('Sepal Length vs Sepal Width')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Sepal Width (cm)')
plt.legend(title='Species')
plt.grid(True)
plt.show()

# Pair Plot: Semua fitur
plt.figure(figsize=(12, 10))
sns.pairplot(df, hue='species', palette='viridis')
plt.title('Pair Plot of Iris Dataset')
plt.show()

# Histogram: Distribusi Sepal Length
plt.figure(figsize=(10, 6))
sns.histplot(df['sepal_length'], kde=True, bins=20, color='blue')
plt.title('Distribution of Sepal Length')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# Box Plot: Sepal Length berdasarkan Species
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='species', y='sepal_length', palette='viridis')
plt.title('Box Plot of Sepal Length by Species')
plt.xlabel('Species')
plt.ylabel('Sepal Length (cm)')
plt.grid(True)
plt.show()
# Out:
# /tmp/ipykernel_1511/817142652.py:36: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='species', y='sepal_length', palette='viridis')
